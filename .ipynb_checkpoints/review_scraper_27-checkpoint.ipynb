# %%
import requests
import pandas as pd

url = "https://store.steampowered.com/appreviews/730?json=1"

response = requests.get(url)
data = response.json()

reviews = data['reviews']

review_list = []

for review in reviews:
    customer_name=review['author']['personaname']
    customer_id = review['author']['steamid']
    comment = review['review']
    votes_up = review['votes_up']
    rating = review['voted_up']

    review_data = {
        'customer_name':customer_name,
        'Customer Steam ID': customer_id,
        'Comment': comment,
        'Votes Up': votes_up,
        'Recommended': rating
    }

    review_list.append(review_data)

df = pd.DataFrame(review_list)

print(df.head(10))

df.to_csv("steam_reviews.csv", index=False)

print("\nSteam Reviews Saved Successfully!")
# Out:
#   customer_name  Customer Steam ID  \
# 0    Mandy_Tren  76561199141679921
# 1      Nirnheim  76561199884102578
# 2          Ropz  76561198878876128
# 3      Laurence  76561199577366977
# 4    FREE SIL3A  76561199850965103
# 5     Vincendio  76561198141430579
# 6     ExXxtremE  76561197981915477
# 7       ℝ𝕒𝕗𝕥𝕪𝕫𝕒  76561199127701778
# 8   paracetamol  76561199236678728
# 9            錯覚  76561198715882977
#
#                                              Comment  Votes Up  Recommended
# 0  Very goood game if you are from Russia or you ...       106         True
# 1  Counter-Strike 2 - this isn’t a shooter, it’s ...       168         True
# 2  Hackers hackers hackers everygame, valve doesn...       125        False
# 3  very interesting game I broke two mice and hea...        43         True
# 4  You play well = cheater\nYou play bad = noob\n...       136        False
# 5  Get yourself a friend, play wingman, go do abs...        30         True
# 6  Counter-Strike 2 is a fantastic game if you en...        24         True
# 7  After 580 hours, I can confidently say my ment...        24        False
# 8  ragebaiting game\nmeet cheater\ngood cheater\n...         8         True
# 9  Absolutely unplayable. CS2 is a massive downgr...        17        False
#
# Steam Reviews Saved Successfully!
